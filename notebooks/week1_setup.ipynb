# %%
import pandas as pd
import numpy as np

print("Social Media Intelligence Project Environment Ready")
# Out:
# Social Media Intelligence Project Environment Ready

# %%
data = {
    "Platform": ["Twitter", "Instagram", "Reddit"],
    "Posts": [1200, 950, 640]
}

df = pd.DataFrame(data)

df
# Out:
#     Platform  Posts
# 0    Twitter   1200
# 1  Instagram    950
# 2     Reddit    640

# %%
df = pd.read_csv('../data/social_media_sample.csv')

df.head()
# Out:
#    id   platform                                      post sentiment
# 0   1    Twitter            The brand service is excellent  Positive
# 1   2  Instagram  Delivery was very slow and disappointing  Negative
# 2   3     Reddit  Customer support solved my issue quickly  Positive
# 3   4    Twitter                Product quality is average   Neutral
# 4   5  Instagram   I love the new update from this company  Positive

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Positive    5
# Negative    4
# Neutral     1
# Name: count, dtype: int64
